# %%
import numpy as np
from itertools import islice

tweetText = []
tweetLabel = []

label_0_dict = {}
label_1_dict = {}
label_2_dict = {}
label_3_dict = {}
label_4_dict = {}
label_5_dict = {}
label_6_dict = {}
label_7_dict = {}
label_8_dict = {}
label_9_dict = {}
label_10_dict = {}
label_11_dict = {}
label_12_dict = {}
label_13_dict = {}
label_14_dict = {}
label_15_dict = {}
label_16_dict = {}
label_17_dict = {}
label_18_dict = {}
label_19_dict = {}
label_20_dict = {}

def reading_data_save_to_array(labelfilename,textfilename):
    
    with open(labelfilename, 'r') as f:
        for line in f:
            line = line.strip()
            tweetLabel.append(line)
            
    
    with open(textfilename, 'r') as f:
        for line in f:
            line = line.strip()
            tweetText.append(line)
    
    dictionary = np.column_stack((tweetLabel,tweetText))
    
    for start, end in dictionary:
        if start == '0':
            for word in end.split():
                if word not in label_0_dict:
                    label_0_dict[word] = 0 
                label_0_dict[word] += 1
    
    print("\nlabel 0 (red heart) top 10 words:")
    for key, value in sorted(label_0_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
    
    
    for start, end in dictionary:
        if start == '1':
            for word in end.split():
                if word not in label_1_dict:
                    label_1_dict[word] = 0 
                label_1_dict[word] += 1
                
    print("\nlabel 1 (smiley face with heart eyes) top 10 words:")
    for key, value in sorted(label_1_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)


    for start, end in dictionary:
        if start == '2':
            for word in end.split():
                if word not in label_2_dict:
                    label_2_dict[word] = 0 
                label_2_dict[word] += 1

    print("\nlabel 2 (laughing face) top 10 words:")
    for key, value in sorted(label_2_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
    
    for start, end in dictionary:
        if start == '3':
            for word in end.split():
                if word not in label_3_dict:
                    label_3_dict[word] = 0 
                label_3_dict[word] += 1

    print("\nlabel 3 (two pink hearts) top 10 words:")
    for key, value in sorted(label_3_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '4':
            for word in end.split():
                if word not in label_4_dict:
                    label_4_dict[word] = 0 
                label_4_dict[word] += 1

    print("\nlabel 4 (flame) top 10 words:")
    for key, value in sorted(label_4_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '5':
            for word in end.split():
                if word not in label_5_dict:
                    label_5_dict[word] = 0 
                label_5_dict[word] += 1

    print("\nlabel 5 (blushing smiley face) top 10 words:")
    for key, value in sorted(label_5_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '6':
            for word in end.split():
                if word not in label_6_dict:
                    label_6_dict[word] = 0 
                label_6_dict[word] += 1

    print("\nlabel 6 (face with sunglsses) top 10 words:")
    for key, value in sorted(label_6_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '7':
            for word in end.split():
                if word not in label_7_dict:
                    label_7_dict[word] = 0 
                label_7_dict[word] += 1

    print("\nlabel 7 (stars) top 10 words:")
    for key, value in sorted(label_7_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '8':
            for word in end.split():
                if word not in label_8_dict:
                    label_8_dict[word] = 0 
                label_8_dict[word] += 1

    print("\nlabel 8 (blue heart) top 10 words:")
    for key, value in sorted(label_8_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '9':
            for word in end.split():
                if word not in label_9_dict:
                    label_9_dict[word] = 0 
                label_9_dict[word] += 1

    print("\nlabel 9 (kissy face) top 10 words:")
    for key, value in sorted(label_9_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '10':
            for word in end.split():
                if word not in label_10_dict:
                    label_10_dict[word] = 0 
                label_10_dict[word] += 1

    print("\nlabel 10 (regular camera) top 10 words:")
    for key, value in sorted(label_10_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '11':
            for word in end.split():
                if word not in label_11_dict:
                    label_11_dict[word] = 0 
                label_11_dict[word] += 1

    print("\nlabel 11 (american flag) top 10 words:")
    for key, value in sorted(label_11_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '12':
            for word in end.split():
                if word not in label_12_dict:
                    label_12_dict[word] = 0 
                label_12_dict[word] += 1

    print("\nlabel 12 (sun) top 10 words:")
    for key, value in sorted(label_12_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '13':
            for word in end.split():
                if word not in label_13_dict:
                    label_13_dict[word] = 0 
                label_13_dict[word] += 1

    print("\nlabel 13 (purple heart) top 10 words:")
    for key, value in sorted(label_13_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
        
    for start, end in dictionary:
        if start == '14':
            for word in end.split():
                if word not in label_14_dict:
                    label_14_dict[word] = 0 
                label_14_dict[word] += 1

    print("\nlabel 14 (winky face) top 10 words:")
    for key, value in sorted(label_14_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '15':
            for word in end.split():
                if word not in label_15_dict:
                    label_15_dict[word] = 0 
                label_15_dict[word] += 1

    print("\nlabel 15 (the 100) top 10 words:")
    for key, value in sorted(label_15_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '16':
            for word in end.split():
                if word not in label_16_dict:
                    label_16_dict[word] = 0 
                label_16_dict[word] += 1

    print("\nlabel 16 (smiley face with teeth) top 10 words:")
    for key, value in sorted(label_16_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)

    for start, end in dictionary:
        if start == '17':
            for word in end.split():
                if word not in label_17_dict:
                    label_17_dict[word] = 0 
                label_17_dict[word] += 1

    print("\nlabel 17 (christmas tree) top 10 words:")
    for key, value in sorted(label_17_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '18':
            for word in end.split():
                if word not in label_18_dict:
                    label_18_dict[word] = 0 
                label_18_dict[word] += 1

    print("\nlabel 18 (camera with flash) top 10 words:")
    for key, value in sorted(label_18_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
    for start, end in dictionary:
        if start == '19':
            for word in end.split():
                if word not in label_19_dict:
                    label_19_dict[word] = 0 
                label_19_dict[word] += 1

    print("\nlabel 19 (winky face with tongue out) top 10 words:")
    for key, value in sorted(label_19_dict.iteritems(), key=lambda (k,v): (v,k), reverse=True)[:15]:
        print "%s: %s" % (key, value)
        
reading_data_save_to_array('tweet_by_ID_08_12_2017__12_37_43.txt.labels','preprocessed_tweets.txt')
# Out:
# label 0 (red heart) top 10 words:
# ️: 99707
# love: 9475
# New: 4453
# Love: 4168
# Happy: 3917
# best: 3117
# ️…: 2820
# We: 2736
# Park: 2502
# night: 2413
# University: 2349
# day: 2283
# much: 2171
# one: 2076
# little: 2031
#
# label 1 (smiley face with heart eyes) top 10 words:
# love: 3146
# New: 2036
# …: 1832
# new: 1211
# night: 1181
# Park: 1102
# beautiful: 1026
# So: 1006
# Love: 1003
# day: 952
# get: 947
# best: 934
# got: 924
# see: 913
# favorite: 896
#
# label 2 (laughing face) top 10 words:
# …: 2281
# like: 2144
# When: 1950
# get: 1517
# New: 1448
# got: 1413
# lol: 1130
# know: 1100
# one: 1050
# love: 1017
# don't: 955
# time: 895
# We: 812
# good: 770
# go: 765
#
# label 3 (two pink hearts) top 10 words:
# love: 2680
# best: 1260
# University: 1130
# Happy: 1122
# …: 1054
# Love: 933
# New: 901
# night: 701
# day: 700
# little: 696
# happy: 665
# much: 655
# birthday: 653
# one: 650
# favorite: 644
#
# label 4 (flame) top 10 words:
# New: 1180
# lit: 1051
# ...
